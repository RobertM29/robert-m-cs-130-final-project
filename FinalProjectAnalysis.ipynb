# %% [markdown]
# Notebook Used For Video Game Anxiety Data Analysis

# %% [markdown]
# Initial Start Of Analysis (Brainstorming/Big Picture)

# %%
import os #helps get the name of the directory for GamingStudy_data.csv 

print(os.getcwd())
print(os.path.abspath('GamingStudy_data.csv'))

import pandas as pd #Pandas library helps capture the data visually within code
gaming_anxiety = pd.read_csv("GamingStudy_data.csv")
print(gaming_anxiety)
# Out:
# C:\Users\rober\Downloads
# C:\Users\rober\Downloads\GamingStudy_data.csv
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
# ...

# %%
gaming_anxiety.head()
# Out:
#    S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0       1  42052.00437     0     0     0     0     1     0     0
# 1       2  42052.00680     1     2     2     2     0     1     0
# 2       3  42052.03860     0     2     2     0     0     3     1
# 3       4  42052.06804     0     0     0     0     0     0     0
# 4       5  42052.08948     2     1     2     2     2     3     2
#
#                    GADE  ...  Birthplace    Residence  Reference  \
# 0  Not difficult at all  ...         USA          USA     Reddit
# 1    Somewhat difficult  ...         USA          USA     Reddit
# 2  Not difficult at all  ...     Germany      Germany     Reddit
# 3  Not difficult at all  ...         USA          USA     Reddit
# 4        Very difficult  ...         USA  South Korea     Reddit
#
#                                            Playstyle  accept GAD_T SWL_T  \
# 0                                       Singleplayer  Accept     1    23
# ...

# %%
def difficulty_count(GADE): 
    count = 0 
    for GADE in 'GamingStudy_data.csv': 
        if " " == GADE:
            count = count + 1 
            return count 
        else: 
            return count 
difficulty_count("Somewhat Difficult")
# Out:
# 0

# %%
def game_count(game):
    count = 0 
    for game in 'GamingStudy_data.csv': 
        if " " == game:
            count = count + 1 
            return count 
    else:
        return count 
game_count("Clash Royale")
# Out:
# 0

# %%
def platform_count(platform): 
    count = 0 
    for platform in 'GamingStudy_data.csv': 
        if " " == platform: 
            count = count + 1 
            return count 
        else: 
            return count

# %%
def whyplay_count(whyplay):
    count = 0 
    for whyplay in 'GamingStudy_data.csv':
        if " " == whyplay: 
            count = count + 1 
            return count 
        else: 
            return count

# %%
def work_count(work): 
    count = 0 
    for work in 'GamingStudy_data.csv': 
        if " " == work: 
            count = count + 1 
            return count 
        else: 
            return count

# %%
def degree_count(degree): 
    count = 0 
    for degree in 'GamingStudy_data.csv': 
        if " " == degree: 
            count = count + 1 
            return count 
        else: 
            return count

# %%
def birthplace_count(Birthplace_ISO3): 
    count = 0 
    for Birthplace_ISO3 in 'GamingStudy_data.csv': 
        if " " == Birthplace_ISO3:
            count = count + 1 
            return count 
        else: 
            return count 
birthplace_count("USA")
# Out:
# 0

# %%
def residence_count(Residence_ISO3): 
    count = 0 
    for residence in 'GamingStudy_data.csv': 
        if " " == Residence_ISO3: 
            count = count + 1 
            return count 
        else: 
            return count

# %%
def playstyle_count(Playstyle):
    count = 0 
    for Playstyle in 'GamingStudy_data.csv': 
        if " " == Playstyle: 
            count = count + 1 
            return count 
        else: 
            return count 
playstyle_count("Multiplayer")
# Out:
# 0

# %%
gaming_anxiety.shape
# Out:
# (13464, 55)

# %%
gaming_anxiety.loc[gaming_anxiety.Birthplace == "USA"]   #Gives the survey responders who said the USA was their birthplace
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13451   14237  42056.67219     0     0     1     0     0     1     0
# 13452   14238  42056.81326     1     0     1     0     0     0     0
# 13454   14240  42056.97403     1     1     1     1     1     1     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.Residence == "USA" #asks how many responders said the USA is where they reside
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 13459    False
# 13460     True
# 13461    False
# 13462    False
# 13463    False
# Name: Residence, Length: 13464, dtype: bool

# %%
gaming_anxiety.Playstyle == "Multiplayer - online - with real life friends" #checks how many responders said they play multiplayer with ppl they know irl
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13459    False
# 13460    False
# 13461     True
# 13462    False
# 13463    False
# Name: Playstyle, Length: 13464, dtype: bool

# %%
gaming_anxiety.Playstyle.value_counts() #gives the amount of responses per type of response for playstyle
# Out:
# Playstyle
# Multiplayer - online - with real life friends                                   5564
# Multiplayer - online - with strangers                                           4134
# Multiplayer - online - with online acquaintances or teammates                   2652
# Singleplayer                                                                     762
# Multiplayer - offline (people in the same room)                                   48
#                                                                                 ...
# A combination of all of the aboive                                                 1
# With real life friends against strangers                                           1
# It's really a bit of all                                                           1
# multiplayer online with online friends                                             1
# I usually play online with my real life friends and the internet ones alike.       1
# ...

# %%
gaming_anxiety.Birthplace.value_counts() #determines the amount of respondents who put a certain country as their birthplace
# Out:
# Birthplace
# USA            4261
# Germany        1376
# UK              940
# Canada          842
# Netherlands     503
#                ...
# Ethiopia          1
# St Vincent        1
# Gibraltar         1
# Brunei            1
# Macau             1
# Name: count, Length: 126, dtype: int64

# %%
gaming_anxiety.Birthplace_ISO3.value_counts() #determines the amount of respondents who put a certain country as their birthplace
# Out:
# Birthplace_ISO3
# USA    4261
# DEU    1376
# GBR     940
# CAN     842
# NLD     503
#        ...
# ETH       1
# VCT       1
# GIB       1
# BRN       1
# MAC       1
# Name: count, Length: 124, dtype: int64

# %%
gaming_anxiety.SWL_T.value_counts() #determines the amount of high scores, low scores, and those between for gamers' satisfaction with life
# Out:
# SWL_T
# 24    636
# 20    607
# 18    606
# 22    600
# 21    595
# 15    590
# 19    588
# 23    587
# 17    580
# 16    576
# 25    569
# 26    568
# 14    550
# 27    540
# 28    525
# 13    503
# 30    477
# 12    476
# 10    441
# 29    425
# 11    414
# 9     341
# 31    304
# 8     246
# 5     244
# 32    203
# 7     184
# 6     145
# 33    137
# 35    114
# 34     93
# Name: count, dtype: int64

# %%
gaming_anxiety.GADE.value_counts() #returns counts of different responses of how gaming affects people's work lives - do they serve as a distraction or do they make people more focused?
# Out:
# GADE
# Not difficult at all    6236
# Somewhat difficult      5148
# Very difficult          1012
# Extremely difficult      419
# Name: count, dtype: int64

# %%
gaming_anxiety.SPIN_T.value_counts() #returns counts of what respondents thought about their social phobia
# Out:
# SPIN_T
# 14.0    444
# 11.0    443
# 12.0    440
# 7.0     426
# 13.0    413
#        ...
# 61.0     10
# 63.0      9
# 67.0      4
# 65.0      3
# 66.0      3
# Name: count, Length: 69, dtype: int64

# %%
gaming_anxiety.Hours.value_counts() #returns the amount of survey respondents per hour input
# Out:
# Hours
# 20.0     2293
# 10.0     1375
# 30.0     1186
# 15.0     1115
# 25.0      831
#          ...
# 420.0       1
# 110.0       1
# 112.0       1
# 96.0        1
# 150.0       1
# Name: count, Length: 84, dtype: int64

# %%
gaming_anxiety.whyplay.value_counts() #returns the statistics for the reasons why survey respondents play videogames
# Out:
# whyplay
# having fun                                   5289
# improving                                    4927
# winning                                      2091
# relaxing                                      654
# All of the above                               26
#                                              ...
# winning, improving AND having fun               1
# talking to irl friends                          1
# Forgetting about my drug addiction              1
# Having fun and improving at the same time       1
# Ranked = winning Normals = Fun                  1
# Name: count, Length: 407, dtype: int64

# %%
gaming_anxiety.League.value_counts() #returns the ranking in-game of each survey respondent
# Out:
# League
# Gold                                             970
# Silver                                           650
# Platinum                                         635
# Diamond                                          549
# gold                                             316
#                                                 ...
# euw                                                1
# Gold 3, but this season goal is plat               1
# Currently unraked, Gold in 2 previous seasons      1
# legendary, masters                                 1
# AHGL                                               1
# Name: count, Length: 1454, dtype: int64

# %%
gaming_anxiety.Gender.value_counts() #returns gender stats for survey respondents
# Out:
# Gender
# Male      12699
# Female      713
# Other        52
# Name: count, dtype: int64

# %%
gaming_anxiety.Age.value_counts() #returns age stats for survey respondents
# Out:
# Age
# 18    3588
# 19    2159
# 20    1855
# 21    1507
# 22    1135
# 23     872
# 24     660
# 25     514
# 26     338
# 27     231
# 28     157
# 29     119
# 30      89
# 31      58
# 32      53
# 33      37
# 34      19
# 35      17
# 36      16
# 38       8
# 42       6
# 39       6
# 37       5
# 41       4
# 50       3
# 40       3
# 44       2
# 63       1
# 49       1
# 56       1
# Name: count, dtype: int64

# %% [markdown]
# Comparison Of Individual Data Sets For Analysis

# %%
gaming_anxiety.loc[gaming_anxiety.Age == 18] #Gives blocks of respondents who were 18 years of age
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 12         13  42052.27609     0     0     0     0     0     0     0
# 15         16  42052.42542     3     1     2     1     0     1     0
# 29         30  42052.68109     0     0     0     0     0     1     0
# 30         31  42052.68394     1     0     1     1     1     2     0
# 40         41  42052.75700     2     2     2     2     2     2     2
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13448   14234  42056.57977     0     0     1     2     1     0     1
# 13451   14237  42056.67219     0     0     1     0     0     1     0
# 13455   14241  42057.02367     1     1     2     0     0     2     0
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.Age < 30] #Gives blocks of respondents who were younger than 30
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# 6           7  42052.14622     0     0     0     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.Age < 40] #Determines survey respondents who are less than 40
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
TotalResponders_count = 13464 
Age18 = 3588
Age19 = 2159 
AgeLessThan30 = 13135
AgeIn20s = AgeLessThan30 - (Age18 + Age19) #calculation determines whom participating in the gaming survey is in 20s 
print("20-30 Year Old Survey Respondents:", AgeIn20s) 
AgeLessThan20 = Age18 + Age19 #calculation determines whom participating in the gaming survey is less than 20 
print("18-19 Year Old Survey Respondents:", AgeLessThan20)
AgeLessThan40 = 13443
AgeIn30s = AgeLessThan40 - AgeIn20s #calculation determines which survey participants are in 30s 
print("30-40 Year Old Survey Respondents:", AgeIn30s) 
TotalResponders_count = 13464 
AgeOlderThan40 = TotalResponders_count - AgeLessThan40 #calculation determines which survey participants are in 40s 
print("40+ Year Old Survey Respondents:", AgeOlderThan40) 

def stats_count(type_amount, TotalResponders_count): #type_amount represents the amount of responders in a given category
    answer = (type_amount/TotalResponders_count) * 100   #finds the percentage of respondents on gaming survey 
    return round(answer,1) 
print("20-30 Yr. Percentage:", stats_count(AgeIn20s, TotalResponders_count),"%") 
print("18-19 Yr. Percentage:", stats_count(AgeLessThan20, TotalResponders_count),"%")
print("30-40 Yr. Percentage:", stats_count(AgeIn30s, TotalResponders_count),"%")
print("40+ Yr. Percentage:", stats_count(AgeOlderThan40, TotalResponders_count),"%")
# Out:
# 20-30 Year Old Survey Respondents: 7388
# 18-19 Year Old Survey Respondents: 5747
# 30-40 Year Old Survey Respondents: 6055
# 40+ Year Old Survey Respondents: 21
# 20-30 Yr. Percentage: 54.9 %
# 18-19 Yr. Percentage: 42.7 %
# 30-40 Yr. Percentage: 45.0 %
# 40+ Yr. Percentage: 0.2 %

# %%
gaming_anxiety.loc[gaming_anxiety.Gender == "Male"]
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
TotalResponders_count = 13464 
MaleResponders_count = 12699 
FemaleResponders_count = TotalResponders_count - MaleResponders_count 

def stats_count(type_amount, TotalResponders_count): #type_amount represents the amount of responders in a given category
    answer = (type_amount/TotalResponders_count) * 100   #finds the percentage of respondents on gaming survey 
    return round(answer,1) 
    
print("Male Responder Percentage:", stats_count(MaleResponders_count, TotalResponders_count),"%") #will find male responder percentage
print("Female Responder Percentage:", stats_count(FemaleResponders_count, TotalResponders_count),"%") #will find female responder percentage
# Out:
# Male Responder Percentage: 94.3 %
# Female Responder Percentage: 5.7 %

# %%
gaming_anxiety.Work.value_counts() #returns work status for survey respondents
# Out:
# Work
# Student at college / university    7073
# Employed                           2734
# Student at school                  2229
# Unemployed / between jobs          1390
# Name: count, dtype: int64

# %%
gaming_anxiety.Degree.value_counts() #returns education status for survey respondents
# Out:
# Degree
# High school diploma (or equivalent)    8560
# Bachelor�(or equivalent)               2687
# Master�(or equivalent)                  546
# Ph.D., Psy. D., MD (or equivalent)       94
# Name: count, dtype: int64

# %%
gaming_anxiety.Playstyle.value_counts() #gives the amount of responses per type of response for playstyle
# Out:
# Playstyle
# Multiplayer - online - with real life friends                                   5564
# Multiplayer - online - with strangers                                           4134
# Multiplayer - online - with online acquaintances or teammates                   2652
# Singleplayer                                                                     762
# Multiplayer - offline (people in the same room)                                   48
#                                                                                 ...
# A combination of all of the aboive                                                 1
# With real life friends against strangers                                           1
# It's really a bit of all                                                           1
# multiplayer online with online friends                                             1
# I usually play online with my real life friends and the internet ones alike.       1
# ...

# %%
Multiplayer_online_irl_friends_count = 5564
Multiplayer_online_strangers_count = 4134
Multiplayer_online_acquaintancesorteammates_count = 2652
Singleplayer_count = 762
Multiplayer_offline_count = 48
print("Multiplayer - online - with real life friends Percentage:", stats_count(Multiplayer_online_irl_friends_count, TotalResponders_count),"%") #finds % of respondents who play mult. online with irl friends
print("Multiplayer - online - with strangers Percentage:", stats_count(Multiplayer_online_strangers_count, TotalResponders_count),"%") #finds % of respondents who play mult. online with strangers
print("Multiplayer - online - with aquaintances or teammates Percentage:", stats_count(Multiplayer_online_acquaintancesorteammates_count, TotalResponders_count),"%") #finds % of respondents who play mult. online with aquaintances or teammates
print("Singleplayer Percentage:", stats_count(Singleplayer_count, TotalResponders_count),"%") #finds % of respondents who play singleplayer
print("Multiplayer Offline Percentage:",  stats_count(Multiplayer_offline_count, TotalResponders_count),"%") #finds % of respondents who play multiplayer offline
PlaystyleCombo_Count = TotalResponders_count - (Multiplayer_online_irl_friends_count + Multiplayer_online_strangers_count + Multiplayer_online_acquaintancesorteammates_count + Singleplayer_count + Multiplayer_offline_count) #calculates respondents with a combination of playstyles
print("Combined Playstyle Percentage:",  stats_count(PlaystyleCombo_Count, TotalResponders_count),"%") #finds % of respondents who use multiple playstyles
# Out:
# Multiplayer - online - with real life friends Percentage: 41.3 %
# Multiplayer - online - with strangers Percentage: 30.7 %
# Multiplayer - online - with aquaintances or teammates Percentage: 19.7 %
# Singleplayer Percentage: 5.7 %
# Multiplayer Offline Percentage: 0.4 %
# Combined Playstyle Percentage: 2.3 %

# %%
gaming_anxiety.League.value_counts() #returns the ranking in-game of each survey respondent
# Out:
# League
# Gold                                             970
# Silver                                           650
# Platinum                                         635
# Diamond                                          549
# gold                                             316
#                                                 ...
# euw                                                1
# Gold 3, but this season goal is plat               1
# Currently unraked, Gold in 2 previous seasons      1
# legendary, masters                                 1
# AHGL                                               1
# Name: count, Length: 1454, dtype: int64

# %%
Gold_count = 970 + 316  
Silver_count = 650 
Platinum_count = 635 
Diamond_count = 549 
Other_Ranks_count = TotalResponders_count - (Gold_count + Silver_count + Platinum_count + Diamond_count) #calculates respondents unranked, climbing to another rank, or receiving a rare ranking (eg. Masters), etc. 
print("Gold Ranking Percentage:", stats_count(Gold_count, TotalResponders_count),"%") 
#Function above determines % of respondents with gold ranking 
print("Silver Ranking Percentage:", stats_count(Silver_count, TotalResponders_count),"%") 
#Function above determines % of respondents with silver ranking 
print("Platnium Ranking Percentage:", stats_count(Platinum_count, TotalResponders_count),"%") 
#Function above determines % of respondents with platnium ranking 
print("Diamond Ranking Percentage:", stats_count(Diamond_count, TotalResponders_count),"%") 
#Function above determines % of respondents with diamond ranking 
print("Other Response For Ranking Percentage:", stats_count(Other_Ranks_count, TotalResponders_count),"%") 
#Function above determines % of respondents with other responses - unranked, climing to another, or another rare ranking (eg. Masters), etc.
# Out:
# Gold Ranking Percentage: 9.6 %
# Silver Ranking Percentage: 4.8 %
# Platnium Ranking Percentage: 4.7 %
# Diamond Ranking Percentage: 4.1 %
# Other Response For Ranking Percentage: 76.8 %

# %%
gaming_anxiety.Birthplace.value_counts() #determines the amount of respondents who put a certain country as their birthplace
# Out:
# Birthplace
# USA            4261
# Germany        1376
# UK              940
# Canada          842
# Netherlands     503
#                ...
# Ethiopia          1
# St Vincent        1
# Gibraltar         1
# Brunei            1
# Macau             1
# Name: count, Length: 126, dtype: int64

# %%
USA_count = 4261
Germany_count = 1376
UK_count = 940
Canada_count = 842
Netherlands_count = 503
Other_BirthCountries_count = TotalResponders_count - (USA_count + Germany_count + UK_count + Canada_count + Netherlands_count) 
#above function calculates respondents from birth countries/places not common in gaming survey 
print("Born In USA Percentage:", stats_count(USA_count, TotalResponders_count),"%") 
#Function above determines % of respondents born in USA
print("Born In Germany Percentage:", stats_count(Germany_count, TotalResponders_count),"%") 
#Function above determines % of respondents born in Germany 
print("Born In UK Percentage:", stats_count(UK_count, TotalResponders_count),"%") 
#Function above determines % of respondents born in UK 
print("Born In Canada Percentage:", stats_count(Canada_count, TotalResponders_count),"%") 
#Function above determines % of respondents born in Canada 
print("Born In Netherlands Percentage:", stats_count(Netherlands_count, TotalResponders_count),"%") 
#Function above determines % of respondents born in Netherlands
print("Born In Other Countries Percentage:", stats_count(Other_BirthCountries_count, TotalResponders_count),"%") 
#Function above determines % of respondents born in uncommon birth countries/places
# Out:
# Born In USA Percentage: 31.6 %
# Born In Germany Percentage: 10.2 %
# Born In UK Percentage: 7.0 %
# Born In Canada Percentage: 6.3 %
# Born In Netherlands Percentage: 3.7 %
# Born In Other Countries Percentage: 41.2 %

# %%
gaming_anxiety.Residence.value_counts() #gives the amount of responses per type of response for residency in a certain country/place
# Out:
# Residence
# USA            4569
# Germany        1413
# UK             1032
# Canada          994
# Netherlands     506
#                ...
# St Vincent        1
# Brunei            1
# Fiji              1
# Gibraltar         1
# Palestine         1
# Name: count, Length: 109, dtype: int64

# %%
USA_Rescount = 4569
Germany_Rescount = 1413
UK_Rescount = 1032
Canada_Rescount = 994
Netherlands_Rescount = 506
Other_ResCountries_count = TotalResponders_count - (USA_Rescount + Germany_Rescount + UK_Rescount + Canada_Rescount + Netherlands_Rescount) 
#above function calculates respondents from birth countries/places not common in gaming survey 
print("Residing In USA Percentage:", stats_count(USA_Rescount, TotalResponders_count),"%") 
#Function above determines % of respondents residing in USA
print("Residing In Germany Percentage:", stats_count(Germany_Rescount, TotalResponders_count),"%") 
#Function above determines % of respondents residing in Germany 
print("Residing In UK Percentage:", stats_count(UK_Rescount, TotalResponders_count),"%") 
#Function above determines % of respondents residing in UK 
print("Residing In Canada Percentage:", stats_count(Canada_Rescount, TotalResponders_count),"%") 
#Function above determines % of respondents residing in Canada 
print("Residing In Netherlands Percentage:", stats_count(Netherlands_Rescount, TotalResponders_count),"%") 
#Function above determines % of respondents residing in Netherlands
print("Residing In Other Countries Percentage:", stats_count(Other_ResCountries_count, TotalResponders_count),"%") 
#Function above determines % of respondents residing from uncommon birth countries/places
# Out:
# Residing In USA Percentage: 33.9 %
# Residing In Germany Percentage: 10.5 %
# Residing In UK Percentage: 7.7 %
# Residing In Canada Percentage: 7.4 %
# Residing In Netherlands Percentage: 3.8 %
# Residing In Other Countries Percentage: 36.8 %

# %%
gaming_anxiety.Hours.value_counts() #returns the amount of survey respondents per hour input
# Out:
# Hours
# 20.0     2293
# 10.0     1375
# 30.0     1186
# 15.0     1115
# 25.0      831
#          ...
# 420.0       1
# 110.0       1
# 112.0       1
# 96.0        1
# 150.0       1
# Name: count, Length: 84, dtype: int64

# %%
gaming_anxiety.loc[gaming_anxiety.Hours < 30] #respondents who game for less than 30 hrs/week
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.Hours < 20] #Respondents who game for less than 20 hrs/week
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 5           6  42052.13119     0     0     0     0     0     1     0
# 8           9  42052.19737     2     3     2     2     0     1     2
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13453   14239  42056.82696     2     0     0     1     1     0     0
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.Hours < 10] #Respondents who game less than 10 hrs/week
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 5           6  42052.13119     0     0     0     0     0     1     0
# 8           9  42052.19737     2     3     2     2     0     1     2
# 16         17  42052.46977     1     0     1     1     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13432   14218  42055.94384     2     0     0     1     0     0     0
# 13435   14221  42056.00784     1     1     2     3     0     1     0
# 13446   14232  42056.43874     0     0     0     0     0     0     0
# 13447   14233  42056.45852     0     0     0     3     1     2     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 1        Somewhat difficult  ...         USA        USA     Reddit
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.Hours > 30] #respondents who game more than 30 hrs/week
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 21         22  42052.65303     3     3     3     2     0     1     3
# 28         29  42052.67252     1     0     2     1     0     0     0
# 59         62  42052.90734     0     0     0     0     0     0     0
# 67         70  42053.07287     0     0     0     0     0     0     0
# 78         81  42053.63137     3     3     3     3     3     3     3
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13420   14206  42055.80003     3     1     3     2     1     3     1
# 13440   14226  42056.23424     1     0     0     0     0     1     0
# 13444   14230  42056.36150     0     0     1     0     0     0     0
# 13454   14240  42056.97403     1     1     1     1     1     1     0
# 13459   14246  42057.75678     1     0     0     1     0     1     1
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 21      Extremely difficult  ...     Germany    Germany      Other
# ...

# %%
LessThan10HourGamers = 1646
LessThan20HourGamers = 6035 
LessThan30HourGamers = 10156 
MoreThan30HourGamers = 2092
print("Less Than 10 Hour Gamers Percentage:", stats_count(LessThan10HourGamers, TotalResponders_count),"%") 
#Function above determines % of respondents who game less than 10 hours a week
print("Less Than 20 Hour Gamers Percentage:", stats_count(LessThan20HourGamers, TotalResponders_count),"%") 
#Function above determines % of respondents who game less than 20 hours a week
print("Less Than 30 Hour Gamers Percentage:", stats_count(LessThan30HourGamers, TotalResponders_count),"%") 
#Function above determines % of respondents who game less than 30 hours a week
print("More Than 30 Hour Gamers Percentage:", stats_count(MoreThan30HourGamers, TotalResponders_count),"%") 
#Function above determines % of respondents who game more than 30 hours a week
# Out:
# Less Than 10 Hour Gamers Percentage: 12.2 %
# Less Than 20 Hour Gamers Percentage: 44.8 %
# Less Than 30 Hour Gamers Percentage: 75.4 %
# More Than 30 Hour Gamers Percentage: 15.5 %

# %%
gaming_anxiety.whyplay.value_counts() #returns the statistics for the reasons why survey respondents play videogames
# Out:
# whyplay
# having fun                                   5289
# improving                                    4927
# winning                                      2091
# relaxing                                      654
# All of the above                               26
#                                              ...
# winning, improving AND having fun               1
# talking to irl friends                          1
# Forgetting about my drug addiction              1
# Having fun and improving at the same time       1
# Ranked = winning Normals = Fun                  1
# Name: count, Length: 407, dtype: int64

# %%
havingfun_count = 5280
improving_count = 4927
winning_count = 2091
relaxing_count = 654
alltheabove_count = 26
other_responses_count = TotalResponders_count - (havingfun_count + improving_count + winning_count + relaxing_count + alltheabove_count) 
#calculation determines the amount of uncommon responses were present when players were asked why they play 
print("Gamers Who Play To Have Fun Percentage:", stats_count(havingfun_count, TotalResponders_count),"%") 
#Function above determines % of respondents mainly playing to have fun 
print("Gamers Who Play To Improve Percentage:", stats_count(improving_count, TotalResponders_count),"%") 
#Function above determines % of respondents mainly playing to improve 
print("Gamers Who Play To Win Percentage:", stats_count(winning_count, TotalResponders_count),"%") 
#Function above determines % of respondents mainly playing to win 
print("Gamers Who Play To Relax Percentage:", stats_count(relaxing_count, TotalResponders_count),"%") 
#Function above determines % of respondents mainly playing to relax/chill out 
print("Gamers Who Play For A Mix Of Having Fun, Improving, Winning, and Relaxing Percentage:", 
      stats_count(alltheabove_count, TotalResponders_count),"%") 
#Function above determines % of respondents mainly playing for a mix of fun, improvement, winning, and relaxation 
print("Other Responses To The Reason Gamers Play Percentage:", stats_count(other_responses_count, TotalResponders_count),"%") 
#Function above determines % of respondents mainly playing for an uncommon response - e.g. talking to irl friends
# Out:
# Gamers Who Play To Have Fun Percentage: 39.2 %
# Gamers Who Play To Improve Percentage: 36.6 %
# Gamers Who Play To Win Percentage: 15.5 %
# Gamers Who Play To Relax Percentage: 4.9 %
# Gamers Who Play For A Mix Of Having Fun, Improving, Winning, and Relaxing Percentage: 0.2 %
# Other Responses To The Reason Gamers Play Percentage: 3.6 %

# %%
gaming_anxiety.SWL_T.value_counts() #determines the amount of high scores, low scores, and those between for gamers' satisfaction with life
# Out:
# SWL_T
# 24    636
# 20    607
# 18    606
# 22    600
# 21    595
# 15    590
# 19    588
# 23    587
# 17    580
# 16    576
# 25    569
# 26    568
# 14    550
# 27    540
# 28    525
# 13    503
# 30    477
# 12    476
# 10    441
# 29    425
# 11    414
# 9     341
# 31    304
# 8     246
# 5     244
# 32    203
# 7     184
# 6     145
# 33    137
# 35    114
# 34     93
# Name: count, dtype: int64

# %%
gaming_anxiety.loc[gaming_anxiety.SWL_T > 30] #respondents who score higher than 30 on Life Satisfaction
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 11         12  42052.26022     0     0     0     0     0     0     0
# 12         13  42052.27609     0     0     0     0     0     0     0
# 19         20  42052.60941     0     0     0     0     0     0     0
# 22         23  42052.66261     0     0     0     1     1     1     0
# 23         24  42052.66336     0     0     0     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13431   14217  42055.91238     0     0     1     0     0     1     0
# 13438   14224  42056.11665     3     3     3     3     3     3     3
# 13440   14226  42056.23424     1     0     0     0     0     1     0
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13461   14248  42058.16964     0     0     0     0     0     0     0
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 11                      NaN  ...         USA        USA     Reddit
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.SWL_T > 20] #respondents who score higher than 20 on Life Satisfaction
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 7           8  42052.15930     0     0     0     0     0     0     0
# 10         11  42052.24204     3     3     3     3     1     3     3
# 11         12  42052.26022     0     0     0     0     0     0     0
# 12         13  42052.27609     0     0     0     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 0      Not difficult at all  ...         USA        USA     Reddit
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.SWL_T < 20] #respondents who score less than 20 on Life Satisfaction
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13454   14240  42056.97403     1     1     1     1     1     1     0
# 13455   14241  42057.02367     1     1     2     0     0     2     0
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
# 13462   14249  42058.24420     3     2     1     3     0     1     3
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.SWL_T < 10] #respondents who score less than 10 on Life Satisfaction
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 18         19  42052.54144     1     1     1     2     2     1     0
# 21         22  42052.65303     3     3     3     2     0     1     3
# 24         25  42052.66394     1     1     1     2     1     2     2
# 25         26  42052.66637     1     0     0     1     0     1     1
# 31         32  42052.69086     3     3     3     3     2     0     1
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13355   14138  42055.64919     1     0     0     0     0     1     0
# 13367   14153  42055.66774     3     2     2     3     0     1     1
# 13396   14182  42055.72323     0     2     3     0     1     2     1
# 13419   14205  42055.79394     3     3     2     2     2     1     1
# 13457   14243  42057.13327     1     2     2     2     0     0     0
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
SWLHighestScore_count = 114 
SWLMoreThan30_count = 851
SWLMoreThan20_count = 6373
SWLLessThan20_count = 6484
SWLLessThan10_count = 1160
SWLLowestScore_count = 244
print("SWL Highest Score Percentage:", stats_count(SWLHighestScore_count, TotalResponders_count),"%") 
#Function above determines % of respondents with the highest SWL score in data 
print("SWL Score > 30 Percentage:", stats_count(SWLMoreThan30_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a SWL score greater than 30 in data 
print("SWL Score > 20 Percentage:", stats_count(SWLMoreThan20_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a SWL score greater than 20 in data  
print("SWL Score < 20 Percentage:", stats_count(SWLLessThan20_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a SWL score less than 20 in data 
print("SWL Score < 10 Percentage:", stats_count(SWLLessThan10_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a SWL score less than 10 in data 
print("SWL Lowest Score Percentage:", stats_count(SWLLowestScore_count, TotalResponders_count),"%") 
#Function above determines % of respondents with the lowest SWL score in data
# Out:
# SWL Highest Score Percentage: 0.8 %
# SWL Score > 30 Percentage: 6.3 %
# SWL Score > 20 Percentage: 47.3 %
# SWL Score < 20 Percentage: 48.2 %
# SWL Score < 10 Percentage: 8.6 %
# SWL Lowest Score Percentage: 1.8 %

# %%
gaming_anxiety.SPIN_T.value_counts() #returns counts of what respondents thought about their social phobia
# Out:
# SPIN_T
# 14.0    444
# 11.0    443
# 12.0    440
# 7.0     426
# 13.0    413
#        ...
# 61.0     10
# 63.0      9
# 67.0      4
# 65.0      3
# 66.0      3
# Name: count, Length: 69, dtype: int64

# %%
gaming_anxiety.loc[gaming_anxiety.SPIN_T > 60] #respondents who score greater than 60 on Social Phobia Inventory (considered to be drastic)
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 63         66  42052.99645     3     3     2     3     1     3     3
# 64         67  42052.99894     2     3     3     3     3     3     2
# 69         72  42053.08773     0     0     0     0     0     0     0
# 72         75  42053.41632     3     2     3     3     0     3     2
# 298       311  42054.61576     0     0     0     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 12860   13617  42055.29430     0     0     0     0     3     0     0
# 12865   13622  42055.29654     3     3     3     3     0     0     3
# 12916   13678  42055.32547     3     3     3     3     2     3     3
# 12974   13736  42055.35955     3     3     3     3     1     2     3
# 12994   13756  42055.36683     3     3     3     2     1     2     3
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 63           Very difficult  ...          UK        USA     Reddit
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.SPIN_T > 15] #respondents who score greater than the most common score on Social Phobia Inventory
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 1           2  42052.00680     1     2     2     2     0     1     0
# 2           3  42052.03860     0     2     2     0     0     3     1
# 6           7  42052.14622     0     0     0     0     0     0     0
# 8           9  42052.19737     2     3     2     2     0     1     2
# 9          10  42052.22995     2     1     2     2     2     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13452   14238  42056.81326     1     0     1     0     0     0     0
# 13453   14239  42056.82696     2     0     0     1     1     0     0
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13462   14249  42058.24420     3     2     1     3     0     1     3
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.SPIN_T < 15] #respondents who score less than the most common score on Social Phobia Inventory
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# 10         11  42052.24204     3     3     3     3     1     3     3
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
gaming_anxiety.loc[gaming_anxiety.SPIN_T < 19] #respondents who score in a good range for Social Phobia Inventory
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# 10         11  42052.24204     3     3     3     3     1     3     3
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
SPINMoreThan60_count = 73
SPINMoreThan15_count = 7053
SPINLessThan15_count = 5373
SPINLessThan19_count = 6887
print("SPIN Score > 60 Percentage:", stats_count(SPINMoreThan60_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a concerningly high SPIN score 
print("SPIN Score > 15 Percentage:", stats_count(SPINMoreThan15_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a SPIN score more than the most commonly responded 
print("SPIN Score < 15 Percentage:", stats_count(SPINLessThan15_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a SPIN score less than the most commonly responded
print("SPIN Score < 19 Percentage:", stats_count(SPINLessThan19_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a SPIN score that is considered good
# Out:
# SPIN Score > 60 Percentage: 0.5 %
# SPIN Score > 15 Percentage: 52.4 %
# SPIN Score < 15 Percentage: 39.9 %
# SPIN Score < 19 Percentage: 51.2 %

# %%
gaming_anxiety.GADE.value_counts() #returns counts of different responses of how gaming affects people's work lives - do they serve as a distraction or do they make people more focused?
# Out:
# GADE
# Not difficult at all    6236
# Somewhat difficult      5148
# Very difficult          1012
# Extremely difficult      419
# Name: count, dtype: int64

# %%
Not_difficult_count = 6236
Somewhat_difficult_count = 5148
Very_difficult_count = 1012
Extremely_difficult_count = 419
print("Not Difficult Percentage:", stats_count(Not_difficult_count, TotalResponders_count),"%") 
#Function above determines % of respondents who believe work is not difficult with gaming in their lives
print("Somewhat difficult Percentage:", stats_count(Somewhat_difficult_count, TotalResponders_count),"%") 
#Function above determines % of respondents who believe work is somewhat difficult with gaming in their lives
print("Very difficult Percentage:", stats_count(Very_difficult_count, TotalResponders_count),"%") 
#Function above determines % of respondents who believe work is very difficult with gaming in their lives
print("Extremely Difficult Percentage:", stats_count(Extremely_difficult_count, TotalResponders_count),"%") 
#Function above determines % of respondents who believe work is extremely difficult with gaming in their lives
# Out:
# Not Difficult Percentage: 46.3 %
# Somewhat difficult Percentage: 38.2 %
# Very difficult Percentage: 7.5 %
# Extremely Difficult Percentage: 3.1 %

# %%
gaming_anxiety.Work.value_counts() #returns work status for survey respondents
# Out:
# Work
# Student at college / university    7073
# Employed                           2734
# Student at school                  2229
# Unemployed / between jobs          1390
# Name: count, dtype: int64

# %%
CollegeorUniversity_count = 7073
Employed_count = 2734
Highschool_count = 2229
Unemployed_BetweenJobs_count = 1390
print("Gamers In College or University Percentage:", stats_count(CollegeorUniversity_count, TotalResponders_count),"%") 
#Function above determines % of respondents currently in college or a university 
print("Employed Gamers Percentage:", stats_count(Employed_count, TotalResponders_count),"%") 
#Function above determines % of respondents who are currently employed
print("Gamers In Highschool Percentage:", stats_count(Highschool_count, TotalResponders_count),"%") 
#Function above determines % of respondents who are currently in highschool
print("Gamers Who Are Unemployed/Between Jobs Percentage:", stats_count(Unemployed_BetweenJobs_count, TotalResponders_count),"%") 
#Function above determines % of respondents who are currently unemployed or in the "off-season" for their job and finding another one
# Out:
# Gamers In College or University Percentage: 52.5 %
# Employed Gamers Percentage: 20.3 %
# Gamers In Highschool Percentage: 16.6 %
# Gamers Who Are Unemployed/Between Jobs Percentage: 10.3 %

# %%
gaming_anxiety.Degree.value_counts() #returns education status for survey respondents
# Out:
# Degree
# High school diploma (or equivalent)    8560
# Bachelor�(or equivalent)               2687
# Master�(or equivalent)                  546
# Ph.D., Psy. D., MD (or equivalent)       94
# Name: count, dtype: int64

# %%
HighSchoolDiploma_count = 8560
Bachelor_Rescount = 2687
Master_Rescount = 546
PHD_PsyD_MD_count = 94
print("High School Diploma Percentage:", stats_count(HighSchoolDiploma_count, TotalResponders_count),"%") 
#Function above determines % of respondents with high school diploma as their highest degree
print("Bachelor's Percentage:", stats_count(Bachelor_Rescount, TotalResponders_count),"%") 
#Function above determines % of respondents with college bachelor's as their highest degree
print("Master's Percentage:", stats_count(Master_Rescount, TotalResponders_count),"%") 
#Function above determines % of respondents with college master's as their highest degree
print("Higher Than Master's Percentage:", stats_count(PHD_PsyD_MD_count, TotalResponders_count),"%") 
#Function above determines % of respondents with a higher degree than master's as their highest degree
# Out:
# High School Diploma Percentage: 63.6 %
# Bachelor's Percentage: 20.0 %
# Master's Percentage: 4.1 %
# Higher Than Master's Percentage: 0.7 %

# %% [markdown]
# Comparison Of Multiple Data Sets For Analysis

# %% [markdown]
# Age & Gender

# %%
gaming_anxiety.loc[(gaming_anxiety.Age == 18) & (gaming_anxiety.Gender == "Female")] 
#function above finds amt of respondents who are female and 18
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 40         41  42052.75700     2     2     2     2     2     2     2
# 62         65  42052.96608     2     2     3     2     2     2     2
# 63         66  42052.99645     3     3     2     3     1     3     3
# 92         95  42053.90690     3     3     3     3     0     0     0
# 129       135  42054.57120     2     3     2     1     0     1     2
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13340   14122  42055.62544     2     1     1     1     0     2     0
# 13357   14140  42055.65126     1     3     3     1     0     1     2
# 13358   14141  42055.65163     0     0     0     0     0     1     0
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13462   14249  42058.24420     3     2     1     3     0     1     3
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
Age18_and_Female_count = 135 
print("Players Who Are 18 and Female:",stats_count(Age18_and_Female_count, TotalResponders_count), "%")
#function above finds % of respondents who are 18 and female
# Out:
# Players Who Are 18 and Female: 1.0 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Age == 18) & (gaming_anxiety.Gender == "Male")]
#function above finds amt of respondents who are male and 18
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 12         13  42052.27609     0     0     0     0     0     0     0
# 15         16  42052.42542     3     1     2     1     0     1     0
# 29         30  42052.68109     0     0     0     0     0     1     0
# 30         31  42052.68394     1     0     1     1     1     2     0
# 41         42  42052.77984     1     1     1     0     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13445   14231  42056.37289     2     1     3     0     3     1     1
# 13447   14233  42056.45852     0     0     0     3     1     2     0
# 13448   14234  42056.57977     0     0     1     2     1     0     1
# 13451   14237  42056.67219     0     0     1     0     0     1     0
# 13455   14241  42057.02367     1     1     2     0     0     2     0
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 12                      NaN  ...         USA        USA     Reddit
# ...

# %%
Age18_and_Male_count = 3441
print("Players Who Are 18 and Male:",stats_count(Age18_and_Male_count, TotalResponders_count), "%")
#function above finds % of respondents who are 18 and male
# Out:
# Players Who Are 18 and Male: 25.6 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Age < 30) & (gaming_anxiety.Gender == "Male")]
#amt of respondents who are male and less than 30
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 3           4  42052.06804     0     0     0     0     0     0     0
# 4           5  42052.08948     2     1     2     2     2     3     2
# 5           6  42052.13119     0     0     0     0     0     1     0
# 6           7  42052.14622     0     0     0     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
# 13459   14246  42057.75678     1     0     0     1     0     1     1
# 13461   14248  42058.16964     0     0     0     0     0     0     0
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...  Birthplace    Residence  Reference  \
# ...

# %%
LessThan30_and_Male_count = 12401
print("Male Players Less Than 30:",stats_count(LessThan30_and_Male_count, TotalResponders_count), "%")
#function above finds % of respondents who are male and less than 30
# Out:
# Male Players Less Than 30: 92.1 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Age < 30) & (gaming_anxiety.Gender == "Female")]
#function above determines respondents who are less than 30 and female
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 7           8  42052.15930     0     0     0     0     0     0     0
# 8           9  42052.19737     2     3     2     2     0     1     2
# 9          10  42052.22995     2     1     2     2     2     1     0
# 10         11  42052.24204     3     3     3     3     1     3     3
# 16         17  42052.46977     1     0     1     1     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13436   14222  42056.08493     0     0     1     0     0     1     0
# 13438   14224  42056.11665     3     3     3     3     3     3     3
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13460   14247  42057.81185     3     3     3     3     2     3     3
# 13462   14249  42058.24420     3     2     1     3     0     1     3
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
LessThan30_and_Female_count = 686
print("Female Players Less Than 30:",stats_count(LessThan30_and_Female_count, TotalResponders_count), "%")
#function above finds % of respondents who are female and less than 30
# Out:
# Female Players Less Than 30: 5.1 %

# %% [markdown]
# Playstyle and League

# %%
gaming_anxiety.loc[(gaming_anxiety.Playstyle == "Multiplayer - online - with real life friends") & (gaming_anxiety.League == "Gold")]
#function determines amt of respondents that play with irl friends online and have a Gold ranking
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 11         12  42052.26022     0     0     0     0     0     0     0
# 77         80  42053.55089     2     1     1     1     0     1     2
# 132       138  42054.57208     1     0     1     2     0     1     1
# 210       219  42054.59995     3     3     3     3     3     3     3
# 216       226  42054.60114     1     0     1     1     3     2     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13321   14100  42055.60736     1     0     1     1     2     1     1
# 13396   14182  42055.72323     0     2     3     0     1     2     1
# 13401   14187  42055.72994     0     2     2     0     2     0     1
# 13444   14230  42056.36150     0     0     1     0     0     0     0
# 13461   14248  42058.16964     0     0     0     0     0     0     0
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 11                      NaN  ...         USA        USA     Reddit
# ...

# %%
gaming_anxiety.loc[(gaming_anxiety.Playstyle == "Multiplayer - online - with real life friends") & (gaming_anxiety.League == "gold")]
#function determines amt of respondents that play with irl friends online and have a gold ranking
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 165       171  42054.58757     1     1     1     0     0     0     1
# 227       239  42054.60368     2     1     1     1     0     1     0
# 296       309  42054.61570     0     0     0     0     0     1     0
# 374       396  42054.62541     0     0     1     0     2     2     0
# 421       446  42054.63030     1     0     0     1     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13107   13875  42055.42484     1     0     0     0     0     0     0
# 13241   14014  42055.52088     0     0     0     0     2     0     0
# 13286   14063  42055.57188     1     0     0     0     0     0     0
# 13358   14141  42055.65163     0     0     0     0     0     1     0
# 13369   14155  42055.66927     0     0     2     2     0     1     2
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 165      Somewhat difficult  ...       Italy    Germany     Reddit
# ...

# %%
Gold_and_MultOnlineRLFriends_count = 152 + 453 #accounts for Gold and gold being the same rank 
print("Gold-Ranked Players Who Play Online W/ IRL Friends:",stats_count(Gold_and_MultOnlineRLFriends_count, TotalResponders_count), "%")
#function above finds % of respondents who play with their irl friends and have a gold ranking
# Out:
# Gold-Ranked Players Who Play Online W/ IRL Friends: 4.5 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Playstyle == "Multiplayer - online - with strangers") & (gaming_anxiety.League == "Gold")]
#amt of respondents who play online with strangers and have a Gold ranking
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 34         35  42052.70229     0     0     0     0     0     2     0
# 35         36  42052.70754     0     0     0     0     0     1     0
# 109       113  42054.56089     1     1     1     1     2     2     1
# 148       154  42054.57986     0     0     0     0     0     0     0
# 214       224  42054.60100     0     0     1     1     0     2     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 12986   13748  42055.36318     0     0     0     0     0     0     0
# 12992   13754  42055.36556     3     0     2     0     0     1     1
# 13106   13874  42055.42465     1     2     1     1     1     1     1
# 13182   13951  42055.47390     1     1     1     1     1     2     0
# 13205   13974  42055.49188     0     0     0     0     0     0     0
#
#                        GADE  ...   Birthplace  Residence       Reference  \
# ...

# %%
gaming_anxiety.loc[(gaming_anxiety.Playstyle == "Multiplayer - online - with strangers") & (gaming_anxiety.League == "gold")]
#amt of respondents who play online with strangers and have a gold ranking
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 280       293  42054.61324     3     3     3     3     3     0     2
# 511       538  42054.63839     3     1     1     2     1     3     1
# 543       576  42054.64193     0     1     1     2     1     1     0
# 612       654  42054.64616     1     0     0     1     0     0     0
# 665       708  42054.64794     0     0     0     0     0     1     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 12423   13144  42055.14379     1     0     0     0     0     0     0
# 12668   13409  42055.20806     0     0     0     0     0     2     0
# 13121   13889  42055.43231     1     2     0     1     0     1     1
# 13153   13921  42055.45851     2     2     0     0     0     0     2
# 13155   13924  42055.45994     1     1     1     1     0     1     1
#
#                        GADE  ...   Birthplace     Residence  Reference  \
# ...

# %%
Gold_and_MultOnlineStrangers_count = 274 + 91 #accounts for Gold and gold being the same rank 
print("Gold-Ranked Players Who Play Online W/ Strangers:",stats_count(Gold_and_MultOnlineStrangers_count, TotalResponders_count), "%")
#function above finds % of respondents who play with strangers and have a gold ranking
# Out:
# Gold-Ranked Players Who Play Online W/ Strangers: 2.7 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Playstyle == "Multiplayer - online - with real life friends") & (gaming_anxiety.League == "Platinum")]
#amt of respondents who play online with irl friends & have a platinum ranking
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 172       179  42054.59095     1     0     0     1     0     1     0
# 234       246  42054.60466     1     0     0     0     0     0     0
# 285       298  42054.61375     3     3     3     3     3     3     3
# 316       331  42054.61771     0     1     1     0     0     2     0
# 334       351  42054.62045     1     0     0     0     0     0     1
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13192   13961  42055.47800     1     1     1     0     1     0     0
# 13193   13962  42055.47928     0     0     0     0     0     1     0
# 13379   14165  42055.68654     1     0     1     0     1     2     0
# 13418   14204  42055.79024     2     1     1     1     1     1     0
# 13428   14214  42055.87618     0     0     1     0     0     1     0
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 172      Somewhat difficult  ...    Portugal   Portugal     Reddit
# ...

# %%
Platinum_and_MultOnlineRLFriends_count = 261 
print("Platinum-Ranked Players Who Play Online W/ IRL Friends:",stats_count(Platinum_and_MultOnlineRLFriends_count, TotalResponders_count), "%")
#function above finds % of respondents who play with their irl friends online and receieved a platinum ranking
# Out:
# Platinum-Ranked Players Who Play Online W/ IRL Friends: 1.9 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Playstyle == "Multiplayer - online - with strangers") & (gaming_anxiety.League == "Platinum")]
#amt of respondents who play online with strangers & have a platinum ranking
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 179       186  42054.59208     0     0     0     0     0     0     0
# 388       413  42054.62723     0     0     0     0     0     0     2
# 430       455  42054.63106     2     0     0     1     0     3     2
# 532       564  42054.64098     2     1     3     2     2     1     1
# 588       629  42054.64522     2     2     2     2     1     2     1
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 12895   13653  42055.31194     3     0     0     0     3     3     0
# 13044   13808  42055.39030     0     0     1     0     0     0     0
# 13156   13925  42055.46005     1     0     0     1     0     0     0
# 13180   13949  42055.47368     0     1     2     1     0     0     3
# 13310   14087  42055.59719     1     0     0     1     0     1     1
#
#                        GADE  ...   Birthplace    Residence  Reference  \
# ...

# %%
Platinum_and_MultOnlineStrangers_count = 197
print("Platinum-Ranked Players Who Play Online W/ Strangers:",stats_count(Platinum_and_MultOnlineStrangers_count, TotalResponders_count), "%")
#function above finds % of respondents who play online with strangers and receieved a platinum ranking
# Out:
# Platinum-Ranked Players Who Play Online W/ Strangers: 1.5 %

# %% [markdown]
# Birthplace & Residence

# %%
gaming_anxiety.loc[(gaming_anxiety.Birthplace == "USA") & (gaming_anxiety.Residence == "USA")]
#amt of respondents born and residing in the USA
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 0           1  42052.00437     0     0     0     0     1     0     0
# 1           2  42052.00680     1     2     2     2     0     1     0
# 3           4  42052.06804     0     0     0     0     0     0     0
# 5           6  42052.13119     0     0     0     0     0     1     0
# 6           7  42052.14622     0     0     0     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13451   14237  42056.67219     0     0     1     0     0     1     0
# 13452   14238  42056.81326     1     0     1     0     0     0     0
# 13454   14240  42056.97403     1     1     1     1     1     1     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
# 13460   14247  42057.81185     3     3     3     3     2     3     3
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 0      Not difficult at all  ...         USA        USA     Reddit
# ...

# %%
Born_and_Res_In_USA_count = 4163 
print("Players Born & Residing In USA:",stats_count(Born_and_Res_In_USA_count, TotalResponders_count), "%")
#function above finds % of respondents who are born and residing in the USA
# Out:
# Players Born & Residing In USA: 30.9 %

# %% [markdown]
# Hours and WhyPlay

# %%
gaming_anxiety.loc[(gaming_anxiety.Hours > 20) & (gaming_anxiety.whyplay == "having fun")] 
#amt of respondents who game more than 20 hrs/week because they mainly like to have fun
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 7           8  42052.15930     0     0     0     0     0     0     0
# 11         12  42052.26022     0     0     0     0     0     0     0
# 14         15  42052.39588     0     0     0     1     0     1     0
# 23         24  42052.66336     0     0     0     0     0     0     0
# 25         26  42052.66637     1     0     0     1     0     1     1
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13424   14210  42055.82860     2     0     2     0     0     1     0
# 13444   14230  42056.36150     0     0     1     0     0     0     0
# 13445   14231  42056.37289     2     1     3     0     3     1     1
# 13449   14235  42056.64020     0     0     0     0     0     1     0
# 13458   14245  42057.35267     0     1     1     1     0     2     1
#
#                        GADE  ...   Birthplace  Residence  Reference  \
# 7                       NaN  ...          USA      Japan     Reddit
# ...

# %%
Morethan20Hrs_and_Havefun_count = 1628
print("Players Gaming More Than 20 Hours To Have Fun:",stats_count(Morethan20Hrs_and_Havefun_count, TotalResponders_count), "%")
#function above finds % of respondents who game > 20 hrs/week and mainly like to have fun
# Out:
# Players Gaming More Than 20 Hours To Have Fun: 12.1 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Hours > 20) & (gaming_anxiety.whyplay == "relaxing")] 
#amt of respondents who game more than 20 hrs/week because they mainly like to have fun
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 6           7  42052.14622     0     0     0     0     0     0     0
# 13         14  42052.30804     0     0     1     0     0     1     1
# 150       156  42054.58083     1     0     0     1     0     1     0
# 172       179  42054.59095     1     0     0     1     0     1     0
# 267       279  42054.61067     1     1     1     1     0     1     1
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13148   13916  42055.45522     1     1     1     0     1     1     2
# 13235   14008  42055.51800     0     0     0     0     0     0     0
# 13274   14051  42055.55612     0     0     1     0     0     1     1
# 13278   14055  42055.55970     2     0     2     2     0     0     0
# 13355   14138  42055.64919     1     0     0     0     0     1     0
#
#                        GADE  ...         Birthplace          Residence  \
# ...

# %%
Morethan20Hrs_and_Relax_count = 200 
print("Players Gaming More Than 20 Hours To Relax:",stats_count(Morethan20Hrs_and_Relax_count, TotalResponders_count), "%")
#function above finds % of respondents who game > 20 hrs/week because they mainly like to relax
# Out:
# Players Gaming More Than 20 Hours To Relax: 1.5 %

# %%
gaming_anxiety.loc[(gaming_anxiety.Hours < 20) & (gaming_anxiety.whyplay == "improving")]
#amt of respondents who game less than 20 hrs/week because they like to improve their skills
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 12         13  42052.27609     0     0     0     0     0     0     0
# 33         34  42052.69547     0     0     0     0     0     0     0
# 37         38  42052.72589     2     2     2     2     2     2     2
# 46         47  42052.83695     1     1     0     0     1     2     0
# 50         52  42052.85654     1     0     1     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13426   14212  42055.85695     1     0     0     1     0     1     1
# 13432   14218  42055.94384     2     0     0     1     0     0     0
# 13439   14225  42056.15273     0     0     0     0     1     0     0
# 13457   14243  42057.13327     1     2     2     2     0     0     0
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                        GADE  ...   Birthplace     Residence  Reference  \
# ...

# %%
LessThan20Hours_and_Improve_count = 1932 
print("Players Gaming Less Than 20 Hours To Improve:",stats_count(LessThan20Hours_and_Improve_count, TotalResponders_count), "%")
#function above finds % of respondents who game less than 20 hrs/week, mainly to improve their skills
# Out:
# Players Gaming Less Than 20 Hours To Improve: 14.3 %

# %% [markdown]
# SWL, SPIN, and GADE

# %%
gaming_anxiety.loc[(gaming_anxiety.SWL_T < 10) & (gaming_anxiety.SPIN_T > 60) & (gaming_anxiety.GADE == "Extremely difficult")]
#amt of respondents with very low life satisfaction, extreme anxiety, and who find gaming a huge distraction from work
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 457       482  42054.63453     3     3     3     3     3     3     3
# 616       658  42054.64618     3     3     3     3     3     3     3
# 973      1030  42054.65794     3     3     3     3     3     3     3
# 2344     2451  42054.69224     3     3     3     2     1     1     3
# 2829     2975  42054.70330     3     3     3     3     3     3     3
# 4102     4302  42054.73509     3     3     3     3     3     2     3
# 5209     5463  42054.76293     3     3     3     3     3     3     0
# 6010     6316  42054.78165     3     3     3     3     3     1     3
# 6126     6440  42054.78517     3     3     3     3     3     3     3
# 9634    10152  42054.90975     3     3     3     3     3     3     3
# 9820    10345  42054.91754     3     3     3     3     3     3     3
# 9870    10398  42054.91971     3     2     2     2     3     0     3
# 10590   11183  42054.95920     3     3     3     3     0     0     2
# ...

# %%
Extreme_concern_count = 16   #amt of respondents w/ low life sat., extreme anxiety, and who find gaming a huge distraction from work 
print("Players Who Find Gaming A Large Detriment:",stats_count(Extreme_concern_count, TotalResponders_count), "%")
#function above finds % of respondents w/ low life satisfaction, extreme anxiety, and find gaming a huge distraction from work
# Out:
# Players Who Find Gaming A Large Detriment: 0.1 %

# %%
gaming_anxiety.loc[(gaming_anxiety.SWL_T > 30) & (gaming_anxiety.SPIN_T < 19) & (gaming_anxiety.GADE == "Not difficult at all")]
#amt of respondents with very high life satisfaction, a healthy/slim amount of anxiety, and who find gaming a great way to focus
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 19         20  42052.60941     0     0     0     0     0     0     0
# 22         23  42052.66261     0     0     0     1     1     1     0
# 56         59  42052.89571     0     0     0     0     0     0     0
# 71         74  42053.23775     0     0     0     0     0     1     0
# 130       136  42054.57196     0     0     1     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13350   14132  42055.64154     0     0     0     0     0     1     0
# 13431   14217  42055.91238     0     0     1     0     0     1     0
# 13438   14224  42056.11665     3     3     3     3     3     3     3
# 13456   14242  42057.06405     1     1     1     0     0     2     0
# 13461   14248  42058.16964     0     0     0     0     0     0     0
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 19     Not difficult at all  ...          UK    Ireland     Reddit
# ...

# %%
Not_worried_count = 435 #amt of respondents with high life sat., healthy/slim amt of anxiety, and find gaming a great way to focus 
print("Players Who Find Gaming A Large Benefit:",stats_count(Not_worried_count, TotalResponders_count), "%")
#function above finds % of respondents w/ a very high life satisfaction, a healthy/slim amt of anxiety, and find gaming a great way to focus
# Out:
# Players Who Find Gaming A Large Benefit: 3.2 %

# %%
gaming_anxiety.loc[(gaming_anxiety.SWL_T > 20) & (gaming_anxiety.SPIN_T < 19) & (gaming_anxiety.GADE == "Somewhat difficult")]
#amt of respondents w/ an avg to good life sat., a healthy/slim amt of anxiety, and find gaming to somewhat distract their focus
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 10         11  42052.24204     3     3     3     3     1     3     3
# 39         40  42052.75257     0     0     1     2     1     1     0
# 44         45  42052.82683     2     1     2     2     2     2     2
# 53         55  42052.87856     2     2     2     1     0     1     0
# 66         69  42053.03369     1     1     1     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13436   14222  42056.08493     0     0     1     0     0     1     0
# 13440   14226  42056.23424     1     0     0     0     0     1     0
# 13445   14231  42056.37289     2     1     3     0     3     1     1
# 13450   14236  42056.66733     0     1     0     0     0     1     1
# 13463   14250  42058.36375     1     1     0     0     0     0     0
#
#                      GADE  ...  Birthplace  Residence  Reference  \
# 10     Somewhat difficult  ...         USA        USA     Reddit
# ...

# %%
Somewhat_worried_count = 1009 
#amt of respondents w/ an avg to good life sat., a healthy/slim amt of anxiety, and find gaming to somewhat distract their focus
print("Players Who Find Gaming A Small Detriment:",stats_count(Somewhat_worried_count, TotalResponders_count), "%")
#function above finds % of respondents w/ w/ an avg to good life sat., a healthy/slim amt of anxiety, and find gaming to somewhat distract their focus
# Out:
# Players Who Find Gaming A Small Detriment: 7.5 %

# %% [markdown]
# Work and Degree

# %%
gaming_anxiety.loc[(gaming_anxiety.Work == "Student at college / university") & (gaming_anxiety.Degree == "Bachelor�(or equivalent)")]
#amt of respondents who are students after highschool and trying to aim for a bachelor's degree
# Out:
#        S. No.    Timestamp  GAD1  GAD2  GAD3  GAD4  GAD5  GAD6  GAD7  \
# 44         45  42052.82683     2     1     2     2     2     2     2
# 64         67  42052.99894     2     3     3     3     3     3     2
# 65         68  42053.02120     1     1     1     0     0     2     1
# 72         75  42053.41632     3     2     3     3     0     3     2
# 75         78  42053.49566     0     0     0     0     0     0     0
# ...       ...          ...   ...   ...   ...   ...   ...   ...   ...
# 13433   14219  42055.95247     0     0     0     0     0     0     0
# 13439   14225  42056.15273     0     0     0     0     1     0     0
# 13444   14230  42056.36150     0     0     1     0     0     0     0
# 13450   14236  42056.66733     0     1     0     0     0     1     1
# 13452   14238  42056.81326     1     0     1     0     0     0     0
#
#                        GADE  ...  Birthplace  Residence  Reference  \
# 44       Somewhat difficult  ...      Canada     Canada     Reddit
# ...

# %%
CollegeorUniversity_and_Bachelor_count = 1216
print("Players Going To College & University To Attain Bachelor's Degree:",stats_count(CollegeorUniversity_and_Bachelor_count, TotalResponders_count), "%")
#function above finds % of respondents who are students after highschool and trying to aim for a bachelor's degree
# Out:
# Players Going To College & University To Attain Bachelor's Degree: 9.0 %

# %% [markdown]
# *Primary Data Used For Article: SWL, SPIN, and GADE Then Hours, whyplay, and playstyle (6/15 DataSets)

# %% [markdown]
# Visualizations For Analysis & Article

# %%
gaming_anxiety.Playstyle.value_counts()
# Out:
# Playstyle
# Multiplayer - online - with real life friends                                   5564
# Multiplayer - online - with strangers                                           4134
# Multiplayer - online - with online acquaintances or teammates                   2652
# Singleplayer                                                                     762
# Multiplayer - offline (people in the same room)                                   48
#                                                                                 ...
# A combination of all of the aboive                                                 1
# With real life friends against strangers                                           1
# It's really a bit of all                                                           1
# multiplayer online with online friends                                             1
# I usually play online with my real life friends and the internet ones alike.       1
# ...

# %%
import matplotlib.pyplot as plt
gaming_style = ["Multiplayer Online", "Singleplayer", "Multiplayer Offline"] 
amt_respondents = [12350, 762, 48]
plt.bar(gaming_style, amt_respondents, color = 'red')
plt.title('How Respondents Play Games')
plt.xlabel('Type of Playstyle')
plt.ylabel('Amount Of Responsents')
plt.show(gaming_style, amt_respondents)

#visualizes Playstyle response data

# %%
gaming_anxiety.Hours.value_counts()
# Out:
# Hours
# 20.0     2293
# 10.0     1375
# 30.0     1186
# 15.0     1115
# 25.0      831
#          ...
# 420.0       1
# 110.0       1
# 112.0       1
# 96.0        1
# 150.0       1
# Name: count, Length: 84, dtype: int64

# %%
import matplotlib.pyplot as plt
gaming_hours = ['Less Than 20', 'Less Than 30', 'More Than 30']
amt_respondents2 = [6035, 10156, 2092]
plt.bar(gaming_hours, amt_respondents2, color = 'red')
plt.title('Average Gaming Hours Per Week')
plt.xlabel('Amount of Hours')
plt.ylabel('Amount Of Responsents')
plt.show()
#visualizes Hours response data

# %%
gaming_anxiety.SWL_T.value_counts()
# Out:
# SWL_T
# 24    636
# 20    607
# 18    606
# 22    600
# 21    595
# 15    590
# 19    588
# 23    587
# 17    580
# 16    576
# 25    569
# 26    568
# 14    550
# 27    540
# 28    525
# 13    503
# 30    477
# 12    476
# 10    441
# 29    425
# 11    414
# 9     341
# 31    304
# 8     246
# 5     244
# 32    203
# 7     184
# 6     145
# 33    137
# 35    114
# 34     93
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
gaming_SWL = ['More Than 20', 'Less Than 20']
amt_respondents3 = [6373, 6484]
plt.bar(gaming_SWL, amt_respondents3, color = 'red')
plt.title('Life Satisfaction Of Gaming Survey Respondents')
plt.xlabel('Satisfied vs Not Satisfied')
plt.ylabel('Amount Of Responsents')
plt.show()
#visualizes SWL score data
